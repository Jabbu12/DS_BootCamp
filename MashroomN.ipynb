# %%
import pandas as pd

# %%
df = pd.read_csv("mushrooms.csv")
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
y=df[['class']]
y
# Out:
#      class
# 0        p
# 1        e
# 2        e
# 3        p
# 4        e
# ...    ...
# 8119     e
# 8120     e
# 8121     e
# 8122     p
# 8123     e
#
# [8124 rows x 1 columns]

# %%
x=df[['cap-shape','cap-surface','cap-color','odor']]

# %%
y.isnull().sum()
# Out:
# class    0
# dtype: int64

# %%
x.isnull().sum()
# Out:
# cap-shape      0
# cap-surface    0
# cap-color      0
# odor           0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(5, 3))
sns.countplot(data=df, x='class')
plt.title('Mushrooms Class')
plt.show()

# %%
class_color = pd.crosstab(df['cap-color'], df['class'])
print(class_color)
# Out:
# class         e     p
# cap-color
# b            48   120
# c            32    12
# e           624   876
# g          1032   808
# n          1264  1020
# p            56    88
# r            16     0
# u            16     0
# w           720   320
# y           400   672

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.countplot(data=df, x='cap-color', hue='class')
plt.title('Mushrooms class by thier cap-c0lor')
plt.show()

# %%
class_surface = pd.crosstab(df['cap-surface'], df['class'])
print(class_surface)
# Out:
# class           e     p
# cap-surface
# f            1560   760
# g               0     4
# s            1144  1412
# y            1504  1740

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.countplot(data=df, x='cap-surface', hue='class')
plt.title('Mushrooms class by thier cap-surface')
plt.show()

# %%
class_shape = pd.crosstab(df['cap-shape'], df['class'])
print(class_shape)
# Out:
# class         e     p
# cap-shape
# b           404    48
# c             0     4
# f          1596  1556
# k           228   600
# s            32     0
# x          1948  1708

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.countplot(data=df, x='cap-shape', hue='class')
plt.title('Mushrooms class by thier cap-shape')
plt.show()

# %%
class_shape = pd.crosstab(df['odor'], df['class'])
print(class_shape)
# Out:
# class     e     p
# odor
# a       400     0
# c         0   192
# f         0  2160
# l       400     0
# m         0    36
# n      3408   120
# p         0   256
# s         0   576
# y         0   576

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.countplot(data=df, x='odor', hue='class')
plt.title('Mushrooms class by thier cap-shape')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()
y['class'] = lb.fit_transform(y['class'])
y
# Out:
# <ipython-input-19-d2b5beb597a7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['class'] = lb.fit_transform(y['class'])
#       class
# 0         1
# 1         0
# 2         0
# 3         1
# 4         0
# ...     ...
# 8119      0
# 8120      0
# 8121      0
# 8122      1
# 8123      0
#
# [8124 rows x 1 columns]

# %%
lb1 = LabelEncoder()
x['cap-shape'] = lb1.fit_transform(x['cap-shape'])

lb2 = LabelEncoder()
x['cap-surface'] = lb2.fit_transform(x['cap-surface'])

lb3 = LabelEncoder()
x['cap-color'] = lb3.fit_transform(x['cap-color'])

lb4 = LabelEncoder()
x['odor'] = lb4.fit_transform(x['odor'])
x
# Out:
# <ipython-input-20-6ee60812fb58>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['cap-shape'] = lb1.fit_transform(x['cap-shape'])
# <ipython-input-20-6ee60812fb58>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['cap-surface'] = lb2.fit_transform(x['cap-surface'])
# <ipython-input-20-6ee60812fb58>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 42, test_size = 0.25)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (6093, 4)
# (6093, 1)
# (2031, 4)
# (2031, 1)

# %%
from sklearn.neighbors import KNeighborsClassifier

clf = KNeighborsClassifier(n_neighbors = 3, p = 1)
clf.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=3, p=1)

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test,y_pred)

# %%
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=True, yticklabels=True)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1040
#            1       1.00      0.98      0.99       991
#
#     accuracy                           0.99      2031
#    macro avg       0.99      0.99      0.99      2031
# weighted avg       0.99      0.99      0.99      2031

# %%
from sklearn.metrics import accuracy_score
accuracies = []
k_values = [x for x in range(1,50,2)]
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k,p=1)
    knn.fit(x_train, y_train)

    y_pred = knn.predict(x_test)

    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)
plt.figure(figsize=(8, 6))
plt.plot(k_values, accuracies, marker='o')
plt.title("Accuracy vs. K Value for k-Nearest Neighbors")
plt.xlabel("K Value")
plt.ylabel("Accuracy")
plt.xticks(k_values)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 42, test_size = 0.25)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (6093, 4)
# (6093, 1)
# (2031, 4)
# (2031, 1)

# %%
from sklearn.naive_bayes import MultinomialNB,BernoulliNB

clf1 = MultinomialNB()
clf2 = BernoulliNB(class_prior=[0.6, 0.6])

# %%
clf1.fit(x_train,y_train)
clf2.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BernoulliNB(class_prior=[0.6, 0.6])

# %%
y_pred1 = clf1.predict(x_test)
y_pred2 = clf2.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm1 = confusion_matrix(y_test,y_pred1)
cr1 = classification_report(y_test,y_pred1)

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm2 = confusion_matrix(y_test,y_pred2)
cr2 = classification_report(y_test,y_pred2)

# %%
print(cr1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.60      0.56      1040
#            1       0.51      0.44      0.47       991
#
#     accuracy                           0.52      2031
#    macro avg       0.52      0.52      0.51      2031
# weighted avg       0.52      0.52      0.51      2031

# %%
print(cr2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.52      0.61      1040
#            1       0.61      0.80      0.69       991
#
#     accuracy                           0.66      2031
#    macro avg       0.67      0.66      0.65      2031
# weighted avg       0.67      0.66      0.65      2031

# %%
from sklearn.metrics import accuracy_score
prior1 = [x/100 for x in range(60,150,5)]
prior2 = [x/100 for x in range(60,150,5)]
best_accuracy = 0.0

best_val1 = None
best_val2 = None

for val2 in prior2:
    for val1 in prior1:
        clf = BernoulliNB(class_prior=[val1, val2])
        clf.fit(x_train, y_train)

        y_pred = clf.predict(x_test)

        acc = accuracy_score(y_test, y_pred)
        if acc > best_accuracy:
            best_accuracy = acc
            best_val1 = val1
            best_val2 = val2

print("Best Accuracy:", best_accuracy)
print("Best val1:", best_val1)
print("Best val2:", best_val2)

# %%
prior1 = [x/100 for x in range(100,200,5)]
prior2 = [x/100 for x in range(0,100,5)]
best_accuracy = 0.0

best_val1 = None
best_val2 = None

for val2 in prior2:
    for val1 in prior1:
        clf = BernoulliNB(class_prior=[0.7, 0.6],alpha = val1,binarize = val2)
        clf.fit(x_train, y_train)

        y_pred = clf.predict(x_test)

        acc = accuracy_score(y_test, y_pred)
        if acc > best_accuracy:
            best_accuracy = acc
            best_val1 = val1
            best_val2 = val2

print("Best Accuracy:", best_accuracy)
print("Best val1:", best_val1)
print("Best val2:", best_val2)
